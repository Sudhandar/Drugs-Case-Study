# %% [markdown]
# # Case Study: DCube Analytics
#
# ### Importing required libraries

# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.feature_selection import SelectKBest,mutual_info_classif,chi2, f_classif
from sklearn.linear_model import LogisticRegression,SGDClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,f1_score,roc_curve, auc,confusion_matrix,classification_report
from imblearn.over_sampling import SMOTE
import xgboost as xgb
# %matplotlib inline

# %% [markdown]
# ### Data Preprocessing

# %%
data = pd.read_csv('../input/input.csv')
data = data.drop_duplicates()
data = data.dropna()
#Changing the column names to lower case
data.columns = [ x.lower().strip() for x in data.columns]
data.columns
# Out:
# Index(['ptid', 'persistency_flag', 'gender', 'race', 'ethnicity', 'region',
#        'age_bucket', 'ntm_speciality', 'ntm_specialist_flag',
#        'ntm_speciality_bucket', 'gluco_record_prior_ntm',
#        'gluco_record_during_rx', 'dexa_freq_during_rx', 'dexa_during_rx',
#        'frag_frac_prior_ntm', 'frag_frac_during_rx', 'risk_segment_prior_ntm',
#        'tscore_bucket_prior_ntm', 'risk_segment_during_rx',
#        'tscore_bucket_during_rx', 'change_t_score', 'change_risk_segment',
#        'adherent_flag', 'idn_indicator', 'injectable_experience_during_rx',
#        'comorb_encounter_for_screening_for_malignant_neoplasms',
#        'comorb_encounter_for_immunization',
#        'comorb_encntr_for_general_exam_w_o_complaint,_susp_or_reprtd_dx',
#        'comorb_vitamin_d_deficiency',
#        'comorb_other_joint_disorder_not_elsewhere_classified',
#        'comorb_encntr_for_oth_sp_exam_w_o_complaint_suspected_or_reprtd_dx',
#        'comorb_long_term_current_drug_therapy', 'comorb_dorsalgia',
#        'comorb_personal_history_of_other_diseases_and_conditions',
#        'comorb_other_disorders_of_bone_density_and_structure',
#        'comorb_disorders_of_lipoprotein_metabolism_and_other_lipidemias',
#        'comorb_osteoporosis_without_current_pathological_fracture',
#        'comorb_personal_history_of_malignant_neoplasm',
#        'comorb_gastro_esophageal_reflux_disease',
#        'concom_cholesterol_and_triglyceride_regulating_preparations',
#        'concom_narcotics', 'concom_systemic_corticosteroids_plain',
#        'concom_anti_depressants_and_mood_stabilisers',
#        'concom_fluoroquinolones', 'concom_cephalosporins',
#        'concom_macrolides_and_similar_types',
#        'concom_broad_spectrum_penicillins', 'concom_anaesthetics_general',
#        'concom_viral_vaccines', 'risk_type_1_insulin_dependent_diabetes',
#        'risk_osteogenesis_imperfecta', 'risk_rheumatoid_arthritis',
#        'risk_untreated_chronic_hyperthyroidism',
#        'risk_untreated_chronic_hypogonadism', 'risk_untreated_early_menopause',
#        'risk_patient_parent_fractured_their_hip', 'risk_smoking_tobacco',
#        'risk_chronic_malnutrition_or_malabsorption',
#        'risk_chronic_liver_disease', 'risk_family_history_of_osteoporosis',
#        'risk_low_calcium_intake', 'risk_vitamin_d_insufficiency',
#        'risk_poor_health_frailty', 'risk_excessive_thinness',
#        'risk_hysterectomy_oophorectomy', 'risk_estrogen_deficiency',
#        'risk_immobilization', 'risk_recurring_falls', 'count_of_risks'],
#       dtype='object')

# %%
data.shape
# Out:
# (3424, 69)

# %%
#Numeric columns present in the data
num_cols = data._get_numeric_data().columns
num_cols
# Out:
# Index(['dexa_freq_during_rx', 'count_of_risks'], dtype='object')

# %% [markdown]
# ### Combining disease and treatment factor columns into frequency counts
#
# The disease and treatment factor columns fall under three categories,
# 1. Concomitancy
# 2. Comorbidity
# 3. Risk Factors
#
# We can convert the individual columns into frequency counts and they are,
# 1. Concomitancy Count
# 2. Comorbidity Count
# 3. Risk Factors Count

# %%
grouping_dict = {}

grouping = ['concom','comorb','risk']

for val in grouping:
    for col in data.columns:
        if col.startswith(val):
            grouping_dict[col] = val

# %% [markdown]
# Each column can be mapped to their respective bucket using a dictionary

# %%
grouping_dict
# Out:
# {'concom_cholesterol_and_triglyceride_regulating_preparations': 'concom',
#  'concom_narcotics': 'concom',
#  'concom_systemic_corticosteroids_plain': 'concom',
#  'concom_anti_depressants_and_mood_stabilisers': 'concom',
#  'concom_fluoroquinolones': 'concom',
#  'concom_cephalosporins': 'concom',
#  'concom_macrolides_and_similar_types': 'concom',
#  'concom_broad_spectrum_penicillins': 'concom',
#  'concom_anaesthetics_general': 'concom',
#  'concom_viral_vaccines': 'concom',
#  'comorb_encounter_for_screening_for_malignant_neoplasms': 'comorb',
#  'comorb_encounter_for_immunization': 'comorb',
#  'comorb_encntr_for_general_exam_w_o_complaint,_susp_or_reprtd_dx': 'comorb',
#  'comorb_vitamin_d_deficiency': 'comorb',
#  'comorb_other_joint_disorder_not_elsewhere_classified': 'comorb',
#  'comorb_encntr_for_oth_sp_exam_w_o_complaint_suspected_or_reprtd_dx': 'comorb',
#  'comorb_long_term_current_drug_therapy': 'comorb',
#  'comorb_dorsalgia': 'comorb',
#  'comorb_personal_history_of_other_diseases_and_conditions': 'comorb',
#  'comorb_other_disorders_of_bone_density_and_structure': 'comorb',
#  'comorb_disorders_of_lipoprotein_metabolism_and_other_lipidemias': 'comorb',
#  'comorb_osteoporosis_without_current_pathological_fracture': 'comorb',
#  'comorb_personal_history_of_malignant_neoplasm': 'comorb',
#  'comorb_gastro_esophageal_reflux_disease': 'comorb',
#  'risk_segment_prior_ntm': 'risk',
#  'risk_segment_during_rx': 'risk',
#  'risk_type_1_insulin_dependent_diabetes': 'risk',
#  'risk_osteogenesis_imperfecta': 'risk',
#  'risk_rheumatoid_arthritis': 'risk',
#  'risk_untreated_chronic_hyperthyroidism': 'risk',
#  'risk_untreated_chronic_hypogonadism': 'risk',
#  'risk_untreated_early_menopause': 'risk',
#  'risk_patient_parent_fractured_their_hip': 'risk',
#  'risk_smoking_tobacco': 'risk',
#  'risk_chronic_malnutrition_or_malabsorption': 'risk',
#  'risk_chronic_liver_disease': 'risk',
#  'risk_family_history_of_osteoporosis': 'risk',
#  'risk_low_calcium_intake': 'risk',
#  'risk_vitamin_d_insufficiency': 'risk',
#  'risk_poor_health_frailty': 'risk',
#  'risk_excessive_thinness': 'risk',
#  'risk_hysterectomy_oophorectomy': 'risk',
#  'risk_estrogen_deficiency': 'risk',
#  'risk_immobilization': 'risk',
#  'risk_recurring_falls': 'risk'}

# %%
# Deleting columns which do not fall under the risk factors bucket
del grouping_dict['risk_segment_prior_ntm']
del grouping_dict['risk_segment_during_rx']

combined_columns = [x for x in grouping_dict.keys()]

# %% [markdown]
# Converting Yes and No values to 1 and 0 using Label Encoding

# %%
le = LabelEncoder()
for val in combined_columns:
    data[val] = le.fit_transform(data[val])

# %% [markdown]
# Grouping the values together using groupby function.

# %%
to_combine = data.set_index('ptid').groupby(grouping_dict,axis=1).sum()

to_combine.columns = ['concomitancy_count','comorbidity_count','risk_factors_count']

to_combine = to_combine.reset_index()

to_combine.head(5)
# Out:
#   ptid  concomitancy_count  comorbidity_count  risk_factors_count
# 0   P1                   5                  0                   0
# 1   P2                   1                  0                   0
# 2   P3                   2                  1                   2
# 3   P4                   6                  3                   1
# 4   P5                   5                  3                   1

# %% [markdown]
# ### Merging the data:
#
# Removing the individual columns and replacing them with their frequency counts

# %%
data = data.drop(combined_columns,axis=1)

data = pd.merge(data, to_combine, on='ptid', how = 'inner')

data=data.drop(['count_of_risks'],axis=1)

# %%
data.shape
# Out:
# (3424, 28)

# %%
data.describe(include='O')
# Out:
#          ptid persistency_flag  gender       race     ethnicity   region  \
# count    3424             3424    3424       3424          3424     3424
# unique   3424                2       2          4             3        5
# top     P2131   Non-Persistent  Female  Caucasian  Not Hispanic  Midwest
# freq        1             2135    3230       3148          3235     1383
#
#        age_bucket        ntm_speciality ntm_specialist_flag  \
# count        3424                  3424                3424
# unique          4                    36                   2
# top           >75  GENERAL PRACTITIONER              Others
# freq         1439                  1535                2013
#
#             ntm_speciality_bucket  ... frag_frac_during_rx  \
# count                        3424  ...                3424
# unique                          3  ...                   2
# top     OB/GYN/Others/PCP/Unknown  ...                   N
# freq                         2104  ...                3007
#
#        risk_segment_prior_ntm tscore_bucket_prior_ntm risk_segment_during_rx  \
# count                    3424                    3424                   3424
# unique                      2                       2                      3
# top                    VLR_LR                   >-2.5                Unknown
# freq                     1931                    1951                   1497
#
#        tscore_bucket_during_rx change_t_score change_risk_segment  \
# count                     3424           3424                3424
# unique                       3              4                   4
# top                    Unknown      No change             Unknown
# freq                      1497           1660                2229
#
#        adherent_flag idn_indicator injectable_experience_during_rx
# count           3424          3424                            3424
# unique             2             2                               2
# top         Adherent             Y                               Y
# freq            3251          2557                            3056
#
# [4 rows x 24 columns]

# %% [markdown]
# ## Feature Engineering
#
# The above table shows that there are four columns with unknown values.Lets explore those columns plotting them.

# %%
fig, axarr = plt.subplots(2, 2, figsize=(17, 15))
data['change_risk_segment'].value_counts().plot.bar(ax=axarr[0][0]).title.set_text('change_risk_segment')
data['risk_segment_during_rx'].value_counts().plot.bar(ax=axarr[0][1]).title.set_text('risk_segment_during_rx')
data['tscore_bucket_during_rx'].value_counts().plot.bar(ax=axarr[1][0]).title.set_text('tscore_bucket_during_rx')
data['change_t_score'].value_counts().plot.bar(ax=axarr[1][1]).title.set_text('change_t_score')

# %% [markdown]
# As we can see from the above graph, the majority of their values are 'Unknown'. These columns would not benefit us, so we can drop them.

# %%
data = data.drop(['change_risk_segment','risk_segment_during_rx','tscore_bucket_during_rx','change_t_score'],axis = 1)

# %% [markdown]
# ### Data Encoding
#
# The majority of the features are **categorical** in nature. So we have to encode them to numerical values.
# We can start by converting the Yes and No values into 1's and 0's.

# %%
#List of yes and no features

binary_cols = ['persistency_flag','gender','ntm_specialist_flag','gluco_record_prior_ntm','gluco_record_during_rx','dexa_during_rx','frag_frac_during_rx','risk_segment_prior_ntm','tscore_bucket_prior_ntm','adherent_flag','idn_indicator','injectable_experience_during_rx','frag_frac_prior_ntm']

# %%
# Using the class instance for label encoding that was created for grouping the relevant buckets

for col in binary_cols:
    data[col] = le.fit_transform(data[col])

# %% [markdown]
# We can drop race and ethnicity which does add value to our model.

# %%
data = data.drop(['race','ethnicity'],axis =1)

# %%
#Encoding features with multiple categories
multiple_class = ['age_bucket','ntm_speciality','ntm_speciality_bucket','region']
for column in multiple_class:
    data[column] = data[column].astype('category')
    data[column] = le.fit_transform(data[column])

# %%
data.dtypes
# Out:
# ptid                               object
# persistency_flag                    int32
# gender                              int32
# region                              int32
# age_bucket                          int32
# ntm_speciality                      int32
# ntm_specialist_flag                 int32
# ntm_speciality_bucket               int32
# gluco_record_prior_ntm              int32
# gluco_record_during_rx              int32
# dexa_freq_during_rx                 int64
# dexa_during_rx                      int32
# frag_frac_prior_ntm                 int32
# frag_frac_during_rx                 int32
# risk_segment_prior_ntm              int32
# tscore_bucket_prior_ntm             int32
# adherent_flag                       int32
# idn_indicator                       int32
# injectable_experience_during_rx     int32
# concomitancy_count                  int64
# comorbidity_count                   int64
# risk_factors_count                  int64
# dtype: object

# %%
data.shape
# Out:
# (3424, 22)

# %% [markdown]
# ## Feature Selection
#
# - There are various feature selection methods for categorical data. I have used the **Mutual Information Classifier** method.
# - Scikit provides a class known Select K best fetaures where we can use *Mutual Information Classifier* in the scoring function parameter.
# - First we have to split the data into features and target after removing the patient id column.

# %%
# Splitting the data into fetaures and target ( persistency_flag ).
features = data.copy()
target = features[['persistency_flag']]
features = features.drop(['ptid','persistency_flag'],axis=1)

# %%
#Creating the class instance for Select K Best module

fs = SelectKBest(score_func=mutual_info_classif,k= 'all')
fs.fit(features , target.values.ravel())
# Out:
# SelectKBest(k='all',
#             score_func=<function mutual_info_classif at 0x0000020E72A01E18>)

# %% [markdown]
# Each feature will be assigned a score based on their relevancy to the taret variable. We can pass those values into a dataframe and sort them based their scores

# %%
feature_columns=features.columns
feature_list = []
for i in range(len(fs.scores_)):
    feature_list.append([feature_columns[i],fs.scores_[i]])
feature_df = pd.DataFrame(feature_list)
feature_df = feature_df.sort_values(1,ascending=False)
feature_df.columns = ['feature','score']
feature_df
# Out:
#                             feature        score
# 17               concomitancy_count  1278.437483
# 9                    dexa_during_rx  1091.855429
# 18                comorbidity_count   522.752276
# 8               dexa_freq_during_rx   433.263198
# 7            gluco_record_during_rx   162.157748
# 4               ntm_specialist_flag    67.801958
# 5             ntm_speciality_bucket    43.957169
# 14                    adherent_flag    43.855470
# 15                    idn_indicator    43.031815
# 11              frag_frac_during_rx    39.583902
# 16  injectable_experience_during_rx    33.430526
# 1                            region    24.559953
# 19               risk_factors_count    23.284954
# 13          tscore_bucket_prior_ntm     1.223237
# 12           risk_segment_prior_ntm     0.511329
# 0                            gender     0.366099
# 6            gluco_record_prior_ntm     0.113449
# 3                    ntm_speciality     0.033798
# 2                        age_bucket     0.013368
# 10              frag_frac_prior_ntm     0.000346

# %% [markdown]
# We shall select the  **top 7** fetaures because they have some significance to the target column whereas the other columns have very low to zero significance.

# %%
selected_columns = feature_df['feature'][:7].tolist()
selected_columns
# Out:
# ['concomitancy_count',
#  'dexa_during_rx',
#  'comorbidity_count',
#  'dexa_freq_during_rx',
#  'gluco_record_during_rx',
#  'ntm_specialist_flag',
#  'ntm_speciality_bucket']

# %% [markdown]
# The above mentioned are the list of seven columns to be used for the model.

# %%
feature_final = features[selected_columns]

# %% [markdown]
# ## Fixing the imbalanced dataset using SMOTE

# %% [markdown]
# Now that we have selected the required features, we can fix the imbalanced dataset.

# %%
target['persistency_flag'].value_counts()
# Out:
# 0    2135
# 1    1289
# Name: persistency_flag, dtype: int64

# %% [markdown]
# There are more 0's **Non-Persistent flags** than 1's **Persistent flag**

# %% [markdown]
# We can oversample our dataset using SMOTE to increase the number of **Persistent Flags**

# %%
oversample = SMOTE()
feature_final,target = oversample.fit_resample(feature_final, target)

# %%
target['persistency_flag'].value_counts()
# Out:
# 1    2135
# 0    2135
# Name: persistency_flag, dtype: int64

# %% [markdown]
# Now there are equal number of 0's and 1's.

# %% [markdown]
# ## Model selection and Training
#
# ### Splitting the data
#
# We shall use a 85-15 split for training and testing sets respectively.

# %%
x_train, x_test,y_train, y_test = train_test_split(feature_final,target,train_size = 0.85, random_state = 8)

# %% [markdown]
# ### Model selection
#
# The following 5 models can be used to evaluate their performance on the given dataset,
#
# 1. Logistic Regression
# 2. K nearest Neighbors
# 3. SVC
# 4. Decision Trees
# 5. Random Forest
#
# We can use the cross validation method to test the models performance and take the AUC score as the evaluation metric.

# %%
# A list to keep track of each model's performance

performance_list=[]

# %% [markdown]
# The following steps are going to be repeated for all the models,
# 1. Creating an instance
# 2. Training the model
# 3. Taking cross validation scores for 10 folds
# 4. Take the mean AUC score

# %% [markdown]
# ### Logistic Regression

# %%
logreg = LogisticRegression()
logreg.fit(x_train, y_train.values.ravel())
scores = cross_val_score(logreg,x_train,y_train.values.ravel(), scoring='f1_weighted', cv=10)
performance_list.append(['Logistic Regression',np.mean(scores)])
print('Mean ROC AUC',np.mean(scores))
# Out:
# Mean ROC AUC 0.7794911958541562

# %% [markdown]
# ### K Nearest Neighbours
#
# Instead of choosing a random number for n_neighbors parameter we can use the cross validation k fold method to find the n_neighbors parameter.

# %%
neighbors = list(range(1, 50, 2))

# empty list that will hold cv scores
cv_scores = []

# perform 10-fold cross validation
for k in neighbors:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, x_train, y_train.values.ravel(), cv=10, scoring='f1_weighted')
    cv_scores.append([k,scores.mean()])
cv_scores
# Out:
# [[1, 0.7225663381868377],
#  [3, 0.7694970112432437],
#  [5, 0.7767061785436218],
#  [7, 0.7742232113237097],
#  [9, 0.7810981511949271],
#  [11, 0.7871937865533822],
#  [13, 0.7832855466069175],
#  [15, 0.7841179388293933],
#  [17, 0.7852445871440678],
#  [19, 0.7847182560623511],
#  [21, 0.7877029107029394],
#  [23, 0.7874674050078236],
#  [25, 0.7888245136481564],
#  [27, 0.7888103742334109],
#  [29, 0.7866166095642545],
#  [31, 0.7866267286239208],
#  [33, 0.791572964817446],
#  [35, 0.7918612257028397],
#  [37, 0.7893544904506447],
#  [39, 0.79157677664244],
#  [41, 0.7940642017169204],
#  [43, 0.793245122656355],
#  [45, 0.796286451576717],
#  [47, 0.7918672501495122],
#  [49, 0.7918880743271075]]

# %% [markdown]
# We shall choose 19 has the n_neighbors parameter since it has the best AUC score.

# %%
knn = KNeighborsClassifier(n_neighbors = 19)
knn.fit(x_train,y_train.values.ravel())
scores = cross_val_score(knn,x_train,y_train.values.ravel(), scoring='f1_weighted', cv=10)
performance_list.append(['K Neighbours Classifiers',np.mean(scores)])
print('Mean ROC AUC',np.mean(scores))
# Out:
# Mean ROC AUC 0.7847182560623511

# %% [markdown]
# ### Support Vector Classifier

# %%
svc = SVC()
svc.fit(x_train,y_train.values.ravel())
scores = cross_val_score(svc,x_train,y_train.values.ravel(), scoring='f1_weighted', cv=10)
performance_list.append(['SVC',np.mean(scores)])
print('Mean ROC AUC',np.mean(scores))
# Out:
# Mean ROC AUC 0.7873195626109193

# %% [markdown]
# ### Decision Tree

# %%
dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
scores = cross_val_score(dtc,x_train,y_train.values.ravel(), scoring='f1_weighted', cv=10)
performance_list.append(['Decision Tree',np.mean(scores)])
print('Mean ROC AUC',np.mean(scores))
# Out:
# Mean ROC AUC 0.7718544389301745

# %% [markdown]
# ### Random Forest

# %%
random_forest = RandomForestClassifier(n_estimators= 150)
random_forest.fit(x_train, y_train.values.ravel())
scores = cross_val_score(random_forest,x_train,y_train.values.ravel(), scoring='f1_weighted', cv=10)
performance_list.append(['Random Forest',np.mean(scores)])
print('Mean ROC AUC',np.mean(scores))
# Out:
# Mean ROC AUC 0.7915841506366939

# %%
xgb_model = xgb.XGBClassifier(n_jobs = -1, max_depth = 7, n_estimators = 100)
xgb_model.fit(x_train, y_train.values.ravel())
scores = cross_val_score(xgb_model,x_train,y_train.values.ravel(), scoring='f1_weighted', cv=10)
performance_list.append(['XGB Model',np.mean(scores)])
print('Mean ROC AUC',np.mean(scores))
# Out:
# Mean ROC AUC 0.7894722541255097

# %% [markdown]
# ## Model Selection
#
# We shall convert the performance metrics list to a dataframe and sort them based on scores.

# %%
performance_df = pd.DataFrame(performance_list)

# %%
performance_df.columns = ['model','train_roc']
performance_df.sort_values('train_roc',ascending = False)
# Out:
#                       model  train_roc
# 5                 XGB Model   0.789472
# 4             Random Forest   0.788829
# 2                       SVC   0.787320
# 1  K Neighbours Classifiers   0.784718
# 0       Logistic Regression   0.779491
# 3             Decision Tree   0.771854

# %% [markdown]
# The K neighbors model has the highest AUC score on the training set. We shall use K Nearest Neighbors to train our model.

# %% [markdown]
# ## Hyperparameter tuning
#
# We can use the grid search method to find the best parameters for our model.

# %%
param_grid = {  "eta": [0.01, 0.015, 0.025], 
              "max_depth": [3, 5, 7, 9, 12],  
              "min_child_weight": [1,3,5,7] ,
             "gamma":[0.1,0.3,0.5]}
fit_params={"early_stopping_rounds":20,"eval_metric": "error","eval_set":[[x_test,y_test]]}

# %%
grid = GridSearchCV(estimator= xgb_model,  param_grid=param_grid,  scoring="f1_weighted", n_jobs=1,  cv= 5 ) 
grid.fit(x_train, y_train.values.ravel(), **fit_params)
# Out:
# [0]	validation_0-error:0.21997
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21373
# [2]	validation_0-error:0.20905
# [3]	validation_0-error:0.21061
# [4]	validation_0-error:0.21061
# [5]	validation_0-error:0.20905
# [6]	validation_0-error:0.20905
# [7]	validation_0-error:0.20593
# [8]	validation_0-error:0.20281
# [9]	validation_0-error:0.21061
# [10]	validation_0-error:0.20749
# [11]	validation_0-error:0.20749
# [12]	validation_0-error:0.20749
# [13]	validation_0-error:0.20749
# [14]	validation_0-error:0.20749
# [15]	validation_0-error:0.20749
# [16]	validation_0-error:0.20749
# [17]	validation_0-error:0.20749
# [18]	validation_0-error:0.20749
# [19]	validation_0-error:0.20749
# [20]	validation_0-error:0.20749
# [21]	validation_0-error:0.20905
# [22]	validation_0-error:0.20905
# [23]	validation_0-error:0.20437
# [24]	validation_0-error:0.20437
# [25]	validation_0-error:0.20437
# [26]	validation_0-error:0.20437
# [27]	validation_0-error:0.20593
# [28]	validation_0-error:0.20593
# Stopping. Best iteration:
# [8]	validation_0-error:0.20281
#
# [0]	validation_0-error:0.23245
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.23245
# [2]	validation_0-error:0.21529
# [3]	validation_0-error:0.21061
# [4]	validation_0-error:0.21061
# [5]	validation_0-error:0.21217
# [6]	validation_0-error:0.20749
# [7]	validation_0-error:0.20593
# [8]	validation_0-error:0.20593
# [9]	validation_0-error:0.20749
# [10]	validation_0-error:0.20749
# [11]	validation_0-error:0.20593
# [12]	validation_0-error:0.20593
# [13]	validation_0-error:0.20593
# [14]	validation_0-error:0.20593
# [15]	validation_0-error:0.20593
# [16]	validation_0-error:0.21061
# [17]	validation_0-error:0.20905
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [18]	validation_0-error:0.20749
# [19]	validation_0-error:0.20437
# [20]	validation_0-error:0.20437
# [21]	validation_0-error:0.20593
# [22]	validation_0-error:0.20593
# [23]	validation_0-error:0.20593
# [24]	validation_0-error:0.20905
# [25]	validation_0-error:0.20905
# [26]	validation_0-error:0.20593
# [27]	validation_0-error:0.20593
# [28]	validation_0-error:0.20593
# [29]	validation_0-error:0.20593
# [30]	validation_0-error:0.20593
# [31]	validation_0-error:0.20593
# [32]	validation_0-error:0.20593
# [33]	validation_0-error:0.20593
# [34]	validation_0-error:0.20593
# [35]	validation_0-error:0.20593
# [36]	validation_0-error:0.20749
# [37]	validation_0-error:0.20749
# [38]	validation_0-error:0.20749
# [39]	validation_0-error:0.20905
# Stopping. Best iteration:
# [19]	validation_0-error:0.20437
#
# [0]	validation_0-error:0.23245
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21373
# [2]	validation_0-error:0.21373
# [3]	validation_0-error:0.21373
# [4]	validation_0-error:0.21373
# [5]	validation_0-error:0.21061
# [6]	validation_0-error:0.21841
# [7]	validation_0-error:0.21685
# [8]	validation_0-error:0.20437
# [9]	validation_0-error:0.20593
# [10]	validation_0-error:0.20593
# [11]	validation_0-error:0.20281
# [12]	validation_0-error:0.20281
# [13]	validation_0-error:0.20437
# [14]	validation_0-error:0.20593
# [15]	validation_0-error:0.20437
# [16]	validation_0-error:0.20437
# [17]	validation_0-error:0.20437
# [18]	validation_0-error:0.20437
# [19]	validation_0-error:0.20437
# [20]	validation_0-error:0.20281
# [21]	validation_0-error:0.20125
# [22]	validation_0-error:0.20125
# [23]	validation_0-error:0.20125
# [24]	validation_0-error:0.20125
# [25]	validation_0-error:0.20125
# [26]	validation_0-error:0.20125
# [27]	validation_0-error:0.20125
# [28]	validation_0-error:0.20125
# [29]	validation_0-error:0.20281
# [30]	validation_0-error:0.20281
# [31]	validation_0-error:0.20281
# [32]	validation_0-error:0.20281
# [33]	validation_0-error:0.20437
# [34]	validation_0-error:0.20437
# [35]	validation_0-error:0.20593
# [36]	validation_0-error:0.20749
# [37]	validation_0-error:0.20749
# [38]	validation_0-error:0.20749
# [39]	validation_0-error:0.20905
# [40]	validation_0-error:0.20749
# [41]	validation_0-error:0.20593
# Stopping. Best iteration:
# [21]	validation_0-error:0.20125
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [0]	validation_0-error:0.23245
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.22153
# [2]	validation_0-error:0.22621
# [3]	validation_0-error:0.22153
# [4]	validation_0-error:0.20905
# [5]	validation_0-error:0.21373
# [6]	validation_0-error:0.20437
# [7]	validation_0-error:0.20749
# [8]	validation_0-error:0.20593
# [9]	validation_0-error:0.20437
# [10]	validation_0-error:0.20905
# [11]	validation_0-error:0.20905
# [12]	validation_0-error:0.20905
# [13]	validation_0-error:0.20905
# [14]	validation_0-error:0.21061
# [15]	validation_0-error:0.21061
# [16]	validation_0-error:0.21061
# [17]	validation_0-error:0.21061
# [18]	validation_0-error:0.21061
# [19]	validation_0-error:0.20905
# [20]	validation_0-error:0.20905
# [21]	validation_0-error:0.20905
# [22]	validation_0-error:0.20905
# [23]	validation_0-error:0.20905
# [24]	validation_0-error:0.20905
# [25]	validation_0-error:0.20905
# [26]	validation_0-error:0.20905
# Stopping. Best iteration:
# [6]	validation_0-error:0.20437
#
# [0]	validation_0-error:0.23245
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.23245
# [2]	validation_0-error:0.20905
# [3]	validation_0-error:0.20905
# [4]	validation_0-error:0.20905
# [5]	validation_0-error:0.21061
# [6]	validation_0-error:0.20905
# [7]	validation_0-error:0.20593
# [8]	validation_0-error:0.21061
# [9]	validation_0-error:0.21061
# [10]	validation_0-error:0.20437
# [11]	validation_0-error:0.20437
# [12]	validation_0-error:0.20905
# [13]	validation_0-error:0.20281
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [14]	validation_0-error:0.20125
# [15]	validation_0-error:0.20125
# [16]	validation_0-error:0.20125
# [17]	validation_0-error:0.20125
# [18]	validation_0-error:0.20125
# [19]	validation_0-error:0.19813
# [20]	validation_0-error:0.19813
# [21]	validation_0-error:0.19813
# [22]	validation_0-error:0.19969
# [23]	validation_0-error:0.19969
# [24]	validation_0-error:0.19969
# [25]	validation_0-error:0.19969
# [26]	validation_0-error:0.19969
# [27]	validation_0-error:0.19969
# [28]	validation_0-error:0.19969
# [29]	validation_0-error:0.19813
# [30]	validation_0-error:0.19813
# [31]	validation_0-error:0.19813
# [32]	validation_0-error:0.19813
# [33]	validation_0-error:0.19813
# [34]	validation_0-error:0.19813
# [35]	validation_0-error:0.19813
# [36]	validation_0-error:0.19813
# [37]	validation_0-error:0.19813
# [38]	validation_0-error:0.19501
# [39]	validation_0-error:0.19345
# [40]	validation_0-error:0.19345
# [41]	validation_0-error:0.19345
# [42]	validation_0-error:0.19345
# [43]	validation_0-error:0.19345
# [44]	validation_0-error:0.19345
# [45]	validation_0-error:0.19345
# [46]	validation_0-error:0.19345
# [47]	validation_0-error:0.19345
# [48]	validation_0-error:0.19345
# [49]	validation_0-error:0.19501
# [50]	validation_0-error:0.19501
# [51]	validation_0-error:0.19501
# [52]	validation_0-error:0.19501
# [53]	validation_0-error:0.19345
# [54]	validation_0-error:0.19345
# [55]	validation_0-error:0.19345
# [56]	validation_0-error:0.19501
# [57]	validation_0-error:0.19501
# [58]	validation_0-error:0.19813
# [59]	validation_0-error:0.19501
# Stopping. Best iteration:
# [39]	validation_0-error:0.19345
#
# [0]	validation_0-error:0.21997
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21373
# [2]	validation_0-error:0.20905
# [3]	validation_0-error:0.21061
# [4]	validation_0-error:0.21061
# [5]	validation_0-error:0.20905
# [6]	validation_0-error:0.20905
# [7]	validation_0-error:0.20593
# [8]	validation_0-error:0.20281
# [9]	validation_0-error:0.21061
# [10]	validation_0-error:0.20749
# [11]	validation_0-error:0.20749
# [12]	validation_0-error:0.20749
# [13]	validation_0-error:0.20749
# [14]	validation_0-error:0.20749
# [15]	validation_0-error:0.20749
# [16]	validation_0-error:0.20749
# [17]	validation_0-error:0.20749
# [18]	validation_0-error:0.20593
# [19]	validation_0-error:0.20593
# [20]	validation_0-error:0.20281
# [21]	validation_0-error:0.20281
# [22]	validation_0-error:0.20281
# [23]	validation_0-error:0.20281
# [24]	validation_0-error:0.20281
# [25]	validation_0-error:0.20281
# [26]	validation_0-error:0.20281
# [27]	validation_0-error:0.20281
# [28]	validation_0-error:0.20437
# Stopping. Best iteration:
# [8]	validation_0-error:0.20281
#
# [0]	validation_0-error:0.23245
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.23245
# [2]	validation_0-error:0.21529
# [3]	validation_0-error:0.21061
# [4]	validation_0-error:0.21061
# [5]	validation_0-error:0.21217
# [6]	validation_0-error:0.20749
# [7]	validation_0-error:0.20749
# [8]	validation_0-error:0.20905
# [9]	validation_0-error:0.20749
# [10]	validation_0-error:0.20593
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [11]	validation_0-error:0.20749
# [12]	validation_0-error:0.20125
# [13]	validation_0-error:0.20437
# [14]	validation_0-error:0.20125
# [15]	validation_0-error:0.20437
# [16]	validation_0-error:0.20281
# [17]	validation_0-error:0.20125
# [18]	validation_0-error:0.20749
# [19]	validation_0-error:0.20281
# [20]	validation_0-error:0.20437
# [21]	validation_0-error:0.20437
# [22]	validation_0-error:0.20437
# [23]	validation_0-error:0.20437
# [24]	validation_0-error:0.20437
# [25]	validation_0-error:0.20593
# [26]	validation_0-error:0.20437
# [27]	validation_0-error:0.20281
# [28]	validation_0-error:0.20593
# [29]	validation_0-error:0.20593
# [30]	validation_0-error:0.20593
# [31]	validation_0-error:0.20749
# [32]	validation_0-error:0.20749
# Stopping. Best iteration:
# [12]	validation_0-error:0.20125
#
# [0]	validation_0-error:0.23245
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21373
# [2]	validation_0-error:0.21373
# [3]	validation_0-error:0.21373
# [4]	validation_0-error:0.21373
# [5]	validation_0-error:0.21061
# [6]	validation_0-error:0.21841
# [7]	validation_0-error:0.21685
# [8]	validation_0-error:0.20437
# [9]	validation_0-error:0.20593
# [10]	validation_0-error:0.20593
# [11]	validation_0-error:0.20281
# [12]	validation_0-error:0.20281
# [13]	validation_0-error:0.20437
# [14]	validation_0-error:0.20593
# [15]	validation_0-error:0.20593
# [16]	validation_0-error:0.20437
# [17]	validation_0-error:0.20281
# [18]	validation_0-error:0.20437
# [19]	validation_0-error:0.20437
# [20]	validation_0-error:0.20437
# [21]	validation_0-error:0.20437
# [22]	validation_0-error:0.20281
# [23]	validation_0-error:0.20281
# [24]	validation_0-error:0.20281
# [25]	validation_0-error:0.20281
# [26]	validation_0-error:0.20281
# [27]	validation_0-error:0.20437
# [28]	validation_0-error:0.20437
# [29]	validation_0-error:0.20437
# [30]	validation_0-error:0.20281
# [31]	validation_0-error:0.20281
# Stopping. Best iteration:
# [11]	validation_0-error:0.20281
#
# [0]	validation_0-error:0.23245
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.22153
# [2]	validation_0-error:0.22621
# [3]	validation_0-error:0.22153
# [4]	validation_0-error:0.20905
# [5]	validation_0-error:0.21373
# [6]	validation_0-error:0.20437
# [7]	validation_0-error:0.20749
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [8]	validation_0-error:0.20593
# [9]	validation_0-error:0.20437
# [10]	validation_0-error:0.20905
# [11]	validation_0-error:0.20905
# [12]	validation_0-error:0.20905
# [13]	validation_0-error:0.20905
# [14]	validation_0-error:0.20905
# [15]	validation_0-error:0.20905
# [16]	validation_0-error:0.20905
# [17]	validation_0-error:0.20905
# [18]	validation_0-error:0.20905
# [19]	validation_0-error:0.20905
# [20]	validation_0-error:0.20749
# [21]	validation_0-error:0.20749
# [22]	validation_0-error:0.20749
# [23]	validation_0-error:0.20749
# [24]	validation_0-error:0.20749
# [25]	validation_0-error:0.20749
# [26]	validation_0-error:0.20749
# Stopping. Best iteration:
# [6]	validation_0-error:0.20437
#
# [0]	validation_0-error:0.23245
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.23245
# [2]	validation_0-error:0.20905
# [3]	validation_0-error:0.20905
# [4]	validation_0-error:0.20905
# [5]	validation_0-error:0.20905
# [6]	validation_0-error:0.20905
# [7]	validation_0-error:0.21061
# [8]	validation_0-error:0.20125
# [9]	validation_0-error:0.19969
# [10]	validation_0-error:0.20125
# [11]	validation_0-error:0.19969
# [12]	validation_0-error:0.20125
# [13]	validation_0-error:0.20125
# [14]	validation_0-error:0.20125
# [15]	validation_0-error:0.19969
# [16]	validation_0-error:0.19969
# [17]	validation_0-error:0.19813
# [18]	validation_0-error:0.19813
# [19]	validation_0-error:0.19813
# [20]	validation_0-error:0.19813
# [21]	validation_0-error:0.19813
# [22]	validation_0-error:0.19813
# [23]	validation_0-error:0.19813
# [24]	validation_0-error:0.19813
# [25]	validation_0-error:0.19813
# [26]	validation_0-error:0.19813
# [27]	validation_0-error:0.19813
# [28]	validation_0-error:0.19969
# [29]	validation_0-error:0.19969
# [30]	validation_0-error:0.19969
# [31]	validation_0-error:0.19969
# [32]	validation_0-error:0.20125
# [33]	validation_0-error:0.20125
# [34]	validation_0-error:0.19657
# [35]	validation_0-error:0.19657
# [36]	validation_0-error:0.19657
# [37]	validation_0-error:0.19657
# [38]	validation_0-error:0.19657
# [39]	validation_0-error:0.19657
# [40]	validation_0-error:0.19657
# [41]	validation_0-error:0.19657
# [42]	validation_0-error:0.19657
# [43]	validation_0-error:0.19657
# [44]	validation_0-error:0.19657
# [45]	validation_0-error:0.19657
# [46]	validation_0-error:0.19657
# [47]	validation_0-error:0.19657
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [48]	validation_0-error:0.19657
# [49]	validation_0-error:0.19657
# [50]	validation_0-error:0.19657
# [51]	validation_0-error:0.19657
# [52]	validation_0-error:0.19501
# [53]	validation_0-error:0.19501
# [54]	validation_0-error:0.19657
# [55]	validation_0-error:0.19657
# [56]	validation_0-error:0.19657
# [57]	validation_0-error:0.19657
# [58]	validation_0-error:0.19657
# [59]	validation_0-error:0.19657
# [60]	validation_0-error:0.19657
# [61]	validation_0-error:0.19657
# [62]	validation_0-error:0.19657
# [63]	validation_0-error:0.19969
# [64]	validation_0-error:0.19969
# [65]	validation_0-error:0.19969
# [66]	validation_0-error:0.19969
# [67]	validation_0-error:0.19969
# [68]	validation_0-error:0.19657
# [69]	validation_0-error:0.19657
# [70]	validation_0-error:0.19657
# [71]	validation_0-error:0.19657
# [72]	validation_0-error:0.19501
# Stopping. Best iteration:
# [52]	validation_0-error:0.19501
#
# [0]	validation_0-error:0.21997
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21373
# [2]	validation_0-error:0.21373
# [3]	validation_0-error:0.21061
# [4]	validation_0-error:0.21061
# [5]	validation_0-error:0.21529
# [6]	validation_0-error:0.21529
# [7]	validation_0-error:0.21373
# [8]	validation_0-error:0.21373
# [9]	validation_0-error:0.21217
# [10]	validation_0-error:0.21061
# [11]	validation_0-error:0.21061
# [12]	validation_0-error:0.21061
# [13]	validation_0-error:0.21061
# [14]	validation_0-error:0.20749
# [15]	validation_0-error:0.21061
# [16]	validation_0-error:0.21061
# [17]	validation_0-error:0.21061
# [18]	validation_0-error:0.20905
# [19]	validation_0-error:0.20905
# [20]	validation_0-error:0.21061
# [21]	validation_0-error:0.21061
# [22]	validation_0-error:0.21061
# [23]	validation_0-error:0.21061
# [24]	validation_0-error:0.20593
# [25]	validation_0-error:0.20593
# [26]	validation_0-error:0.20437
# [27]	validation_0-error:0.20125
# [28]	validation_0-error:0.20281
# [29]	validation_0-error:0.20281
# [30]	validation_0-error:0.20437
# [31]	validation_0-error:0.20437
# [32]	validation_0-error:0.20125
# [33]	validation_0-error:0.20125
# [34]	validation_0-error:0.20125
# [35]	validation_0-error:0.20125
# [36]	validation_0-error:0.19813
# [37]	validation_0-error:0.19813
# [38]	validation_0-error:0.19813
# [39]	validation_0-error:0.19813
# [40]	validation_0-error:0.19969
# [41]	validation_0-error:0.19969
# [42]	validation_0-error:0.19813
# [43]	validation_0-error:0.19813
# [44]	validation_0-error:0.19813
# [45]	validation_0-error:0.19969
# [46]	validation_0-error:0.19813
# [47]	validation_0-error:0.19813
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [48]	validation_0-error:0.19813
# [49]	validation_0-error:0.19813
# [50]	validation_0-error:0.19813
# [51]	validation_0-error:0.19813
# [52]	validation_0-error:0.19813
# [53]	validation_0-error:0.19813
# [54]	validation_0-error:0.19813
# [55]	validation_0-error:0.19813
# [56]	validation_0-error:0.19813
# Stopping. Best iteration:
# [36]	validation_0-error:0.19813
#
# [0]	validation_0-error:0.23245
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.23245
# [2]	validation_0-error:0.21529
# [3]	validation_0-error:0.21529
# [4]	validation_0-error:0.20905
# [5]	validation_0-error:0.20593
# [6]	validation_0-error:0.20593
# [7]	validation_0-error:0.21061
# [8]	validation_0-error:0.21061
# [9]	validation_0-error:0.21217
# [10]	validation_0-error:0.21373
# [11]	validation_0-error:0.20905
# [12]	validation_0-error:0.21061
# [13]	validation_0-error:0.21061
# [14]	validation_0-error:0.20905
# [15]	validation_0-error:0.20905
# [16]	validation_0-error:0.20905
# [17]	validation_0-error:0.21061
# [18]	validation_0-error:0.21061
# [19]	validation_0-error:0.20905
# [20]	validation_0-error:0.21061
# [21]	validation_0-error:0.21061
# [22]	validation_0-error:0.21061
# [23]	validation_0-error:0.20593
# [24]	validation_0-error:0.20593
# [25]	validation_0-error:0.20593
# Stopping. Best iteration:
# [5]	validation_0-error:0.20593
#
# [0]	validation_0-error:0.23245
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21373
# [2]	validation_0-error:0.21373
# [3]	validation_0-error:0.21373
# [4]	validation_0-error:0.21373
# [5]	validation_0-error:0.21061
# [6]	validation_0-error:0.21841
# [7]	validation_0-error:0.21685
# [8]	validation_0-error:0.20437
# [9]	validation_0-error:0.20593
# [10]	validation_0-error:0.20593
# [11]	validation_0-error:0.20281
# [12]	validation_0-error:0.20437
# [13]	validation_0-error:0.20437
# [14]	validation_0-error:0.20593
# [15]	validation_0-error:0.20593
# [16]	validation_0-error:0.20593
# [17]	validation_0-error:0.20437
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [18]	validation_0-error:0.20593
# [19]	validation_0-error:0.20593
# [20]	validation_0-error:0.20593
# [21]	validation_0-error:0.20593
# [22]	validation_0-error:0.20593
# [23]	validation_0-error:0.20593
# [24]	validation_0-error:0.20593
# [25]	validation_0-error:0.20593
# [26]	validation_0-error:0.20593
# [27]	validation_0-error:0.20749
# [28]	validation_0-error:0.20749
# [29]	validation_0-error:0.21061
# [30]	validation_0-error:0.21061
# [31]	validation_0-error:0.21061
# Stopping. Best iteration:
# [11]	validation_0-error:0.20281
#
# [0]	validation_0-error:0.23245
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.22153
# [2]	validation_0-error:0.22621
# [3]	validation_0-error:0.22153
# [4]	validation_0-error:0.22153
# [5]	validation_0-error:0.22465
# [6]	validation_0-error:0.21685
# [7]	validation_0-error:0.21685
# [8]	validation_0-error:0.21685
# [9]	validation_0-error:0.21529
# [10]	validation_0-error:0.21373
# [11]	validation_0-error:0.21373
# [12]	validation_0-error:0.20593
# [13]	validation_0-error:0.20593
# [14]	validation_0-error:0.20437
# [15]	validation_0-error:0.20437
# [16]	validation_0-error:0.20437
# [17]	validation_0-error:0.20437
# [18]	validation_0-error:0.20437
# [19]	validation_0-error:0.20281
# [20]	validation_0-error:0.20281
# [21]	validation_0-error:0.20281
# [22]	validation_0-error:0.20281
# [23]	validation_0-error:0.20281
# [24]	validation_0-error:0.20281
# [25]	validation_0-error:0.20281
# [26]	validation_0-error:0.20125
# [27]	validation_0-error:0.20125
# [28]	validation_0-error:0.20125
# [29]	validation_0-error:0.20125
# [30]	validation_0-error:0.20281
# [31]	validation_0-error:0.20125
# [32]	validation_0-error:0.20125
# [33]	validation_0-error:0.20125
# [34]	validation_0-error:0.20125
# [35]	validation_0-error:0.20125
# [36]	validation_0-error:0.20125
# [37]	validation_0-error:0.19969
# [38]	validation_0-error:0.19813
# [39]	validation_0-error:0.19969
# [40]	validation_0-error:0.20437
# [41]	validation_0-error:0.20749
# [42]	validation_0-error:0.20125
# [43]	validation_0-error:0.20281
# [44]	validation_0-error:0.20281
# [45]	validation_0-error:0.20593
# [46]	validation_0-error:0.20749
# [47]	validation_0-error:0.20905
# [48]	validation_0-error:0.20905
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [49]	validation_0-error:0.20749
# [50]	validation_0-error:0.20905
# [51]	validation_0-error:0.20749
# [52]	validation_0-error:0.20749
# [53]	validation_0-error:0.20749
# [54]	validation_0-error:0.20749
# [55]	validation_0-error:0.20749
# [56]	validation_0-error:0.20749
# [57]	validation_0-error:0.20749
# [58]	validation_0-error:0.20593
# Stopping. Best iteration:
# [38]	validation_0-error:0.19813
#
# [0]	validation_0-error:0.23245
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.23245
# [2]	validation_0-error:0.20905
# [3]	validation_0-error:0.20905
# [4]	validation_0-error:0.20905
# [5]	validation_0-error:0.20905
# [6]	validation_0-error:0.20905
# [7]	validation_0-error:0.20905
# [8]	validation_0-error:0.19969
# [9]	validation_0-error:0.20125
# [10]	validation_0-error:0.20125
# [11]	validation_0-error:0.20281
# [12]	validation_0-error:0.20125
# [13]	validation_0-error:0.20437
# [14]	validation_0-error:0.20281
# [15]	validation_0-error:0.19813
# [16]	validation_0-error:0.19657
# [17]	validation_0-error:0.19813
# [18]	validation_0-error:0.19813
# [19]	validation_0-error:0.19813
# [20]	validation_0-error:0.19813
# [21]	validation_0-error:0.19657
# [22]	validation_0-error:0.19501
# [23]	validation_0-error:0.19501
# [24]	validation_0-error:0.19345
# [25]	validation_0-error:0.19501
# [26]	validation_0-error:0.19501
# [27]	validation_0-error:0.19501
# [28]	validation_0-error:0.19501
# [29]	validation_0-error:0.19501
# [30]	validation_0-error:0.19501
# [31]	validation_0-error:0.19501
# [32]	validation_0-error:0.19501
# [33]	validation_0-error:0.19501
# [34]	validation_0-error:0.19501
# [35]	validation_0-error:0.19501
# [36]	validation_0-error:0.19345
# [37]	validation_0-error:0.19345
# [38]	validation_0-error:0.19345
# [39]	validation_0-error:0.19345
# [40]	validation_0-error:0.19345
# [41]	validation_0-error:0.19345
# [42]	validation_0-error:0.19501
# [43]	validation_0-error:0.19501
# [44]	validation_0-error:0.19501
# Stopping. Best iteration:
# [24]	validation_0-error:0.19345
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [0]	validation_0-error:0.21997
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21373
# [2]	validation_0-error:0.21373
# [3]	validation_0-error:0.21061
# [4]	validation_0-error:0.21529
# [5]	validation_0-error:0.21373
# [6]	validation_0-error:0.21373
# [7]	validation_0-error:0.21529
# [8]	validation_0-error:0.21373
# [9]	validation_0-error:0.21061
# [10]	validation_0-error:0.21217
# [11]	validation_0-error:0.21217
# [12]	validation_0-error:0.21217
# [13]	validation_0-error:0.21373
# [14]	validation_0-error:0.21373
# [15]	validation_0-error:0.21373
# [16]	validation_0-error:0.21373
# [17]	validation_0-error:0.21373
# [18]	validation_0-error:0.21373
# [19]	validation_0-error:0.21373
# [20]	validation_0-error:0.21373
# [21]	validation_0-error:0.21217
# [22]	validation_0-error:0.21061
# [23]	validation_0-error:0.21217
# Stopping. Best iteration:
# [3]	validation_0-error:0.21061
#
# [0]	validation_0-error:0.23245
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.23245
# [2]	validation_0-error:0.21529
# [3]	validation_0-error:0.21061
# [4]	validation_0-error:0.21061
# [5]	validation_0-error:0.21217
# [6]	validation_0-error:0.20749
# [7]	validation_0-error:0.20905
# [8]	validation_0-error:0.20749
# [9]	validation_0-error:0.20593
# [10]	validation_0-error:0.20749
# [11]	validation_0-error:0.21061
# [12]	validation_0-error:0.21217
# [13]	validation_0-error:0.20905
# [14]	validation_0-error:0.20905
# [15]	validation_0-error:0.20749
# [16]	validation_0-error:0.21061
# [17]	validation_0-error:0.21061
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [18]	validation_0-error:0.21061
# [19]	validation_0-error:0.21061
# [20]	validation_0-error:0.20749
# [21]	validation_0-error:0.20749
# [22]	validation_0-error:0.20905
# [23]	validation_0-error:0.20905
# [24]	validation_0-error:0.20905
# [25]	validation_0-error:0.20905
# [26]	validation_0-error:0.20905
# [27]	validation_0-error:0.20749
# [28]	validation_0-error:0.20905
# [29]	validation_0-error:0.20749
# Stopping. Best iteration:
# [9]	validation_0-error:0.20593
#
# [0]	validation_0-error:0.23245
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21373
# [2]	validation_0-error:0.21373
# [3]	validation_0-error:0.21373
# [4]	validation_0-error:0.21373
# [5]	validation_0-error:0.21061
# [6]	validation_0-error:0.21841
# [7]	validation_0-error:0.20437
# [8]	validation_0-error:0.20437
# [9]	validation_0-error:0.21217
# [10]	validation_0-error:0.20437
# [11]	validation_0-error:0.20593
# [12]	validation_0-error:0.20593
# [13]	validation_0-error:0.20593
# [14]	validation_0-error:0.20593
# [15]	validation_0-error:0.20593
# [16]	validation_0-error:0.20749
# [17]	validation_0-error:0.20749
# [18]	validation_0-error:0.20593
# [19]	validation_0-error:0.20749
# [20]	validation_0-error:0.20749
# [21]	validation_0-error:0.20749
# [22]	validation_0-error:0.20593
# [23]	validation_0-error:0.20749
# [24]	validation_0-error:0.20593
# [25]	validation_0-error:0.20437
# [26]	validation_0-error:0.20437
# [27]	validation_0-error:0.20593
# Stopping. Best iteration:
# [7]	validation_0-error:0.20437
#
# [0]	validation_0-error:0.23245
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.22153
# [2]	validation_0-error:0.22153
# [3]	validation_0-error:0.22621
# [4]	validation_0-error:0.21217
# [5]	validation_0-error:0.21061
# [6]	validation_0-error:0.21061
# [7]	validation_0-error:0.21217
# [8]	validation_0-error:0.21217
# [9]	validation_0-error:0.21217
# [10]	validation_0-error:0.21061
# [11]	validation_0-error:0.21061
# [12]	validation_0-error:0.21061
# [13]	validation_0-error:0.21061
# [14]	validation_0-error:0.21217
# [15]	validation_0-error:0.20749
# [16]	validation_0-error:0.20749
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [17]	validation_0-error:0.20905
# [18]	validation_0-error:0.20905
# [19]	validation_0-error:0.20905
# [20]	validation_0-error:0.20905
# [21]	validation_0-error:0.20905
# [22]	validation_0-error:0.20905
# [23]	validation_0-error:0.20905
# [24]	validation_0-error:0.20905
# [25]	validation_0-error:0.20905
# [26]	validation_0-error:0.20749
# [27]	validation_0-error:0.20749
# [28]	validation_0-error:0.20749
# [29]	validation_0-error:0.20749
# [30]	validation_0-error:0.20749
# [31]	validation_0-error:0.20749
# [32]	validation_0-error:0.20749
# [33]	validation_0-error:0.20749
# [34]	validation_0-error:0.20749
# [35]	validation_0-error:0.20749
# Stopping. Best iteration:
# [15]	validation_0-error:0.20749
#
# [0]	validation_0-error:0.23245
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.23245
# [2]	validation_0-error:0.20905
# [3]	validation_0-error:0.20905
# [4]	validation_0-error:0.20905
# [5]	validation_0-error:0.20905
# [6]	validation_0-error:0.20905
# [7]	validation_0-error:0.20905
# [8]	validation_0-error:0.19969
# [9]	validation_0-error:0.20125
# [10]	validation_0-error:0.20125
# [11]	validation_0-error:0.20281
# [12]	validation_0-error:0.20281
# [13]	validation_0-error:0.19969
# [14]	validation_0-error:0.19969
# [15]	validation_0-error:0.19969
# [16]	validation_0-error:0.19969
# [17]	validation_0-error:0.19969
# [18]	validation_0-error:0.19969
# [19]	validation_0-error:0.19969
# [20]	validation_0-error:0.19813
# [21]	validation_0-error:0.19813
# [22]	validation_0-error:0.19501
# [23]	validation_0-error:0.19501
# [24]	validation_0-error:0.19657
# [25]	validation_0-error:0.19501
# [26]	validation_0-error:0.19657
# [27]	validation_0-error:0.19657
# [28]	validation_0-error:0.19657
# [29]	validation_0-error:0.19501
# [30]	validation_0-error:0.19345
# [31]	validation_0-error:0.19345
# [32]	validation_0-error:0.19345
# [33]	validation_0-error:0.19345
# [34]	validation_0-error:0.19345
# [35]	validation_0-error:0.19345
# [36]	validation_0-error:0.19345
# [37]	validation_0-error:0.19345
# [38]	validation_0-error:0.19345
# [39]	validation_0-error:0.19345
# [40]	validation_0-error:0.19345
# [41]	validation_0-error:0.19345
# [42]	validation_0-error:0.19345
# [43]	validation_0-error:0.19345
# [44]	validation_0-error:0.19345
# [45]	validation_0-error:0.19345
# [46]	validation_0-error:0.19501
# [47]	validation_0-error:0.19501
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [48]	validation_0-error:0.19501
# [49]	validation_0-error:0.19501
# [50]	validation_0-error:0.19813
# Stopping. Best iteration:
# [30]	validation_0-error:0.19345
#
# [0]	validation_0-error:0.21373
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21373
# [2]	validation_0-error:0.21373
# [3]	validation_0-error:0.21373
# [4]	validation_0-error:0.21217
# [5]	validation_0-error:0.21841
# [6]	validation_0-error:0.21529
# [7]	validation_0-error:0.21217
# [8]	validation_0-error:0.21061
# [9]	validation_0-error:0.21217
# [10]	validation_0-error:0.21061
# [11]	validation_0-error:0.21061
# [12]	validation_0-error:0.21373
# [13]	validation_0-error:0.21373
# [14]	validation_0-error:0.21529
# [15]	validation_0-error:0.21529
# [16]	validation_0-error:0.21841
# [17]	validation_0-error:0.22153
# [18]	validation_0-error:0.22153
# [19]	validation_0-error:0.22153
# [20]	validation_0-error:0.22153
# [21]	validation_0-error:0.21997
# [22]	validation_0-error:0.21997
# [23]	validation_0-error:0.21997
# [24]	validation_0-error:0.22465
# [25]	validation_0-error:0.22465
# [26]	validation_0-error:0.22465
# [27]	validation_0-error:0.22309
# [28]	validation_0-error:0.22309
# Stopping. Best iteration:
# [8]	validation_0-error:0.21061
#
# [0]	validation_0-error:0.21529
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21529
# [2]	validation_0-error:0.21685
# [3]	validation_0-error:0.21529
# [4]	validation_0-error:0.21841
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [5]	validation_0-error:0.21061
# [6]	validation_0-error:0.21217
# [7]	validation_0-error:0.21217
# [8]	validation_0-error:0.21373
# [9]	validation_0-error:0.21685
# [10]	validation_0-error:0.22153
# [11]	validation_0-error:0.22153
# [12]	validation_0-error:0.21529
# [13]	validation_0-error:0.21373
# [14]	validation_0-error:0.21217
# [15]	validation_0-error:0.21373
# [16]	validation_0-error:0.21529
# [17]	validation_0-error:0.21529
# [18]	validation_0-error:0.21529
# [19]	validation_0-error:0.21373
# [20]	validation_0-error:0.21529
# [21]	validation_0-error:0.21529
# [22]	validation_0-error:0.21217
# [23]	validation_0-error:0.21217
# [24]	validation_0-error:0.21217
# [25]	validation_0-error:0.21217
# Stopping. Best iteration:
# [5]	validation_0-error:0.21061
#
# [0]	validation_0-error:0.21529
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21685
# [2]	validation_0-error:0.21217
# [3]	validation_0-error:0.21217
# [4]	validation_0-error:0.21529
# [5]	validation_0-error:0.21373
# [6]	validation_0-error:0.20593
# [7]	validation_0-error:0.20749
# [8]	validation_0-error:0.20437
# [9]	validation_0-error:0.20593
# [10]	validation_0-error:0.20749
# [11]	validation_0-error:0.20905
# [12]	validation_0-error:0.21061
# [13]	validation_0-error:0.20905
# [14]	validation_0-error:0.20905
# [15]	validation_0-error:0.20905
# [16]	validation_0-error:0.20905
# [17]	validation_0-error:0.21061
# [18]	validation_0-error:0.20905
# [19]	validation_0-error:0.21373
# [20]	validation_0-error:0.21373
# [21]	validation_0-error:0.21373
# [22]	validation_0-error:0.21217
# [23]	validation_0-error:0.20905
# [24]	validation_0-error:0.20905
# [25]	validation_0-error:0.20593
# [26]	validation_0-error:0.20749
# [27]	validation_0-error:0.20749
# [28]	validation_0-error:0.20749
# Stopping. Best iteration:
# [8]	validation_0-error:0.20437
#
# [0]	validation_0-error:0.21529
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21997
# [2]	validation_0-error:0.21685
# [3]	validation_0-error:0.21061
# [4]	validation_0-error:0.21529
# [5]	validation_0-error:0.21061
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [6]	validation_0-error:0.21061
# [7]	validation_0-error:0.21529
# [8]	validation_0-error:0.21217
# [9]	validation_0-error:0.21373
# [10]	validation_0-error:0.21373
# [11]	validation_0-error:0.21373
# [12]	validation_0-error:0.21373
# [13]	validation_0-error:0.21529
# [14]	validation_0-error:0.21529
# [15]	validation_0-error:0.21529
# [16]	validation_0-error:0.21529
# [17]	validation_0-error:0.21685
# [18]	validation_0-error:0.21685
# [19]	validation_0-error:0.21529
# [20]	validation_0-error:0.21685
# [21]	validation_0-error:0.21529
# [22]	validation_0-error:0.21529
# [23]	validation_0-error:0.21529
# Stopping. Best iteration:
# [3]	validation_0-error:0.21061
#
# [0]	validation_0-error:0.21529
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21841
# [2]	validation_0-error:0.21997
# [3]	validation_0-error:0.21217
# [4]	validation_0-error:0.21217
# [5]	validation_0-error:0.21217
# [6]	validation_0-error:0.21217
# [7]	validation_0-error:0.21373
# [8]	validation_0-error:0.21685
# [9]	validation_0-error:0.21685
# [10]	validation_0-error:0.21373
# [11]	validation_0-error:0.21217
# [12]	validation_0-error:0.21529
# [13]	validation_0-error:0.21529
# [14]	validation_0-error:0.21529
# [15]	validation_0-error:0.21529
# [16]	validation_0-error:0.21217
# [17]	validation_0-error:0.21373
# [18]	validation_0-error:0.21373
# [19]	validation_0-error:0.20905
# [20]	validation_0-error:0.21061
# [21]	validation_0-error:0.20749
# [22]	validation_0-error:0.20749
# [23]	validation_0-error:0.20905
# [24]	validation_0-error:0.20905
# [25]	validation_0-error:0.21217
# [26]	validation_0-error:0.21217
# [27]	validation_0-error:0.21217
# [28]	validation_0-error:0.21217
# [29]	validation_0-error:0.21061
# [30]	validation_0-error:0.21061
# [31]	validation_0-error:0.21217
# [32]	validation_0-error:0.21217
# [33]	validation_0-error:0.21217
# [34]	validation_0-error:0.21217
# [35]	validation_0-error:0.21217
# [36]	validation_0-error:0.21217
# [37]	validation_0-error:0.21217
# [38]	validation_0-error:0.21373
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [39]	validation_0-error:0.21373
# [40]	validation_0-error:0.21373
# [41]	validation_0-error:0.21217
# Stopping. Best iteration:
# [21]	validation_0-error:0.20749
#
# [0]	validation_0-error:0.21217
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21061
# [2]	validation_0-error:0.21061
# [3]	validation_0-error:0.21217
# [4]	validation_0-error:0.21217
# [5]	validation_0-error:0.21373
# [6]	validation_0-error:0.21373
# [7]	validation_0-error:0.21061
# [8]	validation_0-error:0.20749
# [9]	validation_0-error:0.20749
# [10]	validation_0-error:0.21217
# [11]	validation_0-error:0.20593
# [12]	validation_0-error:0.20437
# [13]	validation_0-error:0.20125
# [14]	validation_0-error:0.19969
# [15]	validation_0-error:0.20125
# [16]	validation_0-error:0.19969
# [17]	validation_0-error:0.20437
# [18]	validation_0-error:0.20437
# [19]	validation_0-error:0.20593
# [20]	validation_0-error:0.20905
# [21]	validation_0-error:0.21061
# [22]	validation_0-error:0.21061
# [23]	validation_0-error:0.21061
# [24]	validation_0-error:0.21061
# [25]	validation_0-error:0.21061
# [26]	validation_0-error:0.21061
# [27]	validation_0-error:0.21217
# [28]	validation_0-error:0.21061
# [29]	validation_0-error:0.21217
# [30]	validation_0-error:0.21529
# [31]	validation_0-error:0.21217
# [32]	validation_0-error:0.21217
# [33]	validation_0-error:0.21373
# [34]	validation_0-error:0.21841
# Stopping. Best iteration:
# [14]	validation_0-error:0.19969
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [0]	validation_0-error:0.20749
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.20905
# [2]	validation_0-error:0.21061
# [3]	validation_0-error:0.21061
# [4]	validation_0-error:0.21061
# [5]	validation_0-error:0.20437
# [6]	validation_0-error:0.20437
# [7]	validation_0-error:0.20437
# [8]	validation_0-error:0.20437
# [9]	validation_0-error:0.20593
# [10]	validation_0-error:0.20593
# [11]	validation_0-error:0.20437
# [12]	validation_0-error:0.20437
# [13]	validation_0-error:0.20593
# [14]	validation_0-error:0.20437
# [15]	validation_0-error:0.20593
# [16]	validation_0-error:0.20593
# [17]	validation_0-error:0.20593
# [18]	validation_0-error:0.20593
# [19]	validation_0-error:0.20437
# [20]	validation_0-error:0.20437
# [21]	validation_0-error:0.20593
# [22]	validation_0-error:0.20593
# [23]	validation_0-error:0.20593
# [24]	validation_0-error:0.20593
# [25]	validation_0-error:0.20749
# Stopping. Best iteration:
# [5]	validation_0-error:0.20437
#
# [0]	validation_0-error:0.21529
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21217
# [2]	validation_0-error:0.21373
# [3]	validation_0-error:0.20749
# [4]	validation_0-error:0.21061
# [5]	validation_0-error:0.20749
# [6]	validation_0-error:0.20749
# [7]	validation_0-error:0.20125
# [8]	validation_0-error:0.20281
# [9]	validation_0-error:0.20125
# [10]	validation_0-error:0.20281
# [11]	validation_0-error:0.20125
# [12]	validation_0-error:0.20125
# [13]	validation_0-error:0.20281
# [14]	validation_0-error:0.20437
# [15]	validation_0-error:0.20281
# [16]	validation_0-error:0.19969
# [17]	validation_0-error:0.20281
# [18]	validation_0-error:0.20437
# [19]	validation_0-error:0.20749
# [20]	validation_0-error:0.19813
# [21]	validation_0-error:0.19657
# [22]	validation_0-error:0.19657
# [23]	validation_0-error:0.20437
# [24]	validation_0-error:0.20437
# [25]	validation_0-error:0.20281
# [26]	validation_0-error:0.20125
# [27]	validation_0-error:0.20437
# [28]	validation_0-error:0.20437
# [29]	validation_0-error:0.20281
# [30]	validation_0-error:0.19969
# [31]	validation_0-error:0.20437
# [32]	validation_0-error:0.20437
# [33]	validation_0-error:0.20437
# [34]	validation_0-error:0.20437
# [35]	validation_0-error:0.20437
# [36]	validation_0-error:0.20437
# [37]	validation_0-error:0.20593
# [38]	validation_0-error:0.20593
# [39]	validation_0-error:0.20437
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [40]	validation_0-error:0.20749
# [41]	validation_0-error:0.20593
# Stopping. Best iteration:
# [21]	validation_0-error:0.19657
#
# [0]	validation_0-error:0.21373
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21529
# [2]	validation_0-error:0.21529
# [3]	validation_0-error:0.20905
# [4]	validation_0-error:0.21061
# [5]	validation_0-error:0.21373
# [6]	validation_0-error:0.21061
# [7]	validation_0-error:0.21061
# [8]	validation_0-error:0.21061
# [9]	validation_0-error:0.20749
# [10]	validation_0-error:0.20905
# [11]	validation_0-error:0.21217
# [12]	validation_0-error:0.21061
# [13]	validation_0-error:0.21217
# [14]	validation_0-error:0.21217
# [15]	validation_0-error:0.21217
# [16]	validation_0-error:0.21217
# [17]	validation_0-error:0.21061
# [18]	validation_0-error:0.21061
# [19]	validation_0-error:0.21217
# [20]	validation_0-error:0.21685
# [21]	validation_0-error:0.21373
# [22]	validation_0-error:0.21217
# [23]	validation_0-error:0.21061
# [24]	validation_0-error:0.20905
# [25]	validation_0-error:0.20749
# [26]	validation_0-error:0.20749
# [27]	validation_0-error:0.21061
# [28]	validation_0-error:0.21061
# [29]	validation_0-error:0.21061
# Stopping. Best iteration:
# [9]	validation_0-error:0.20749
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [0]	validation_0-error:0.21529
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21373
# [2]	validation_0-error:0.21685
# [3]	validation_0-error:0.21061
# [4]	validation_0-error:0.21061
# [5]	validation_0-error:0.21061
# [6]	validation_0-error:0.20593
# [7]	validation_0-error:0.20281
# [8]	validation_0-error:0.20281
# [9]	validation_0-error:0.20281
# [10]	validation_0-error:0.20281
# [11]	validation_0-error:0.20281
# [12]	validation_0-error:0.20281
# [13]	validation_0-error:0.21061
# [14]	validation_0-error:0.20593
# [15]	validation_0-error:0.20593
# [16]	validation_0-error:0.20749
# [17]	validation_0-error:0.20749
# [18]	validation_0-error:0.20905
# [19]	validation_0-error:0.20749
# [20]	validation_0-error:0.20749
# [21]	validation_0-error:0.20749
# [22]	validation_0-error:0.20749
# [23]	validation_0-error:0.20749
# [24]	validation_0-error:0.20749
# [25]	validation_0-error:0.20437
# [26]	validation_0-error:0.20437
# [27]	validation_0-error:0.20281
# Stopping. Best iteration:
# [7]	validation_0-error:0.20281
#
# [0]	validation_0-error:0.21061
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21061
# [2]	validation_0-error:0.21217
# [3]	validation_0-error:0.21061
# [4]	validation_0-error:0.21061
# [5]	validation_0-error:0.21061
# [6]	validation_0-error:0.21061
# [7]	validation_0-error:0.20905
# [8]	validation_0-error:0.21061
# [9]	validation_0-error:0.20749
# [10]	validation_0-error:0.20905
# [11]	validation_0-error:0.20905
# [12]	validation_0-error:0.20905
# [13]	validation_0-error:0.20593
# [14]	validation_0-error:0.20593
# [15]	validation_0-error:0.20749
# [16]	validation_0-error:0.20749
# [17]	validation_0-error:0.20593
# [18]	validation_0-error:0.20593
# [19]	validation_0-error:0.20905
# [20]	validation_0-error:0.20905
# [21]	validation_0-error:0.21373
# [22]	validation_0-error:0.21217
# [23]	validation_0-error:0.21373
# [24]	validation_0-error:0.21373
# [25]	validation_0-error:0.21373
# [26]	validation_0-error:0.21529
# [27]	validation_0-error:0.21217
# [28]	validation_0-error:0.21061
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [29]	validation_0-error:0.21529
# [30]	validation_0-error:0.21529
# [31]	validation_0-error:0.21373
# [32]	validation_0-error:0.21217
# [33]	validation_0-error:0.21529
# Stopping. Best iteration:
# [13]	validation_0-error:0.20593
#
# [0]	validation_0-error:0.20749
# ...
# [1]	validation_0-error:0.22465
# [2]	validation_0-error:0.22777
# [3]	validation_0-error:0.22153
# [4]	validation_0-error:0.21841
# [5]	validation_0-error:0.21997
# [6]	validation_0-error:0.21685
# [7]	validation_0-error:0.21685
# [8]	validation_0-error:0.21529
# [9]	validation_0-error:0.21529
# [10]	validation_0-error:0.21529
# [11]	validation_0-error:0.22153
# [12]	validation_0-error:0.22309
# [13]	validation_0-error:0.22309
# [14]	validation_0-error:0.22621
# [15]	validation_0-error:0.22465
# [16]	validation_0-error:0.23245
# [17]	validation_0-error:0.22933
# [18]	validation_0-error:0.23089
# [19]	validation_0-error:0.23089
# [20]	validation_0-error:0.23401
# Stopping. Best iteration:
# [0]	validation_0-error:0.21217
#
# [0]	validation_0-error:0.20905
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21997
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [2]	validation_0-error:0.22153
# [3]	validation_0-error:0.21529
# [4]	validation_0-error:0.21217
# [5]	validation_0-error:0.21529
# [6]	validation_0-error:0.21997
# [7]	validation_0-error:0.21997
# [8]	validation_0-error:0.21217
# [9]	validation_0-error:0.21373
# [10]	validation_0-error:0.21529
# [11]	validation_0-error:0.21373
# [12]	validation_0-error:0.22153
# [13]	validation_0-error:0.22621
# [14]	validation_0-error:0.22153
# [15]	validation_0-error:0.22153
# [16]	validation_0-error:0.22309
# [17]	validation_0-error:0.22153
# [18]	validation_0-error:0.22465
# [19]	validation_0-error:0.22621
# [20]	validation_0-error:0.22621
# Stopping. Best iteration:
# [0]	validation_0-error:0.20905
#
# [0]	validation_0-error:0.20593
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.20593
# [2]	validation_0-error:0.20437
# [3]	validation_0-error:0.20281
# [4]	validation_0-error:0.20593
# [5]	validation_0-error:0.21061
# [6]	validation_0-error:0.20749
# [7]	validation_0-error:0.20905
# [8]	validation_0-error:0.21061
# [9]	validation_0-error:0.20593
# [10]	validation_0-error:0.20749
# [11]	validation_0-error:0.20749
# [12]	validation_0-error:0.20749
# [13]	validation_0-error:0.20593
# [14]	validation_0-error:0.20593
# [15]	validation_0-error:0.20749
# [16]	validation_0-error:0.20593
# [17]	validation_0-error:0.20437
# [18]	validation_0-error:0.20593
# [19]	validation_0-error:0.20749
# [20]	validation_0-error:0.20905
# [21]	validation_0-error:0.20749
# [22]	validation_0-error:0.20749
# [23]	validation_0-error:0.20749
# Stopping. Best iteration:
# [3]	validation_0-error:0.20281
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [0]	validation_0-error:0.21529
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21217
# [2]	validation_0-error:0.21061
# [3]	validation_0-error:0.21061
# [4]	validation_0-error:0.21061
# [5]	validation_0-error:0.21841
# [6]	validation_0-error:0.21997
# [7]	validation_0-error:0.21997
# [8]	validation_0-error:0.22153
# [9]	validation_0-error:0.22153
# [10]	validation_0-error:0.22153
# [11]	validation_0-error:0.22465
# [12]	validation_0-error:0.22153
# [13]	validation_0-error:0.22309
# [14]	validation_0-error:0.21997
# [15]	validation_0-error:0.22465
# [16]	validation_0-error:0.22465
# [17]	validation_0-error:0.22309
# [18]	validation_0-error:0.21841
# [19]	validation_0-error:0.21841
# [20]	validation_0-error:0.22153
# [21]	validation_0-error:0.22465
# [22]	validation_0-error:0.22465
# Stopping. Best iteration:
# [2]	validation_0-error:0.21061
#
# [0]	validation_0-error:0.20905
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.20593
# [2]	validation_0-error:0.19969
# [3]	validation_0-error:0.21061
# [4]	validation_0-error:0.20749
# [5]	validation_0-error:0.20593
# [6]	validation_0-error:0.21061
# [7]	validation_0-error:0.20905
# [8]	validation_0-error:0.20281
# [9]	validation_0-error:0.20593
# [10]	validation_0-error:0.20593
# [11]	validation_0-error:0.20593
# [12]	validation_0-error:0.20437
# [13]	validation_0-error:0.20905
# [14]	validation_0-error:0.20749
# [15]	validation_0-error:0.20749
# [16]	validation_0-error:0.21061
# [17]	validation_0-error:0.21217
# [18]	validation_0-error:0.21061
# [19]	validation_0-error:0.21061
# [20]	validation_0-error:0.21061
# [21]	validation_0-error:0.20593
# [22]	validation_0-error:0.21061
# Stopping. Best iteration:
# [2]	validation_0-error:0.19969
#
# [0]	validation_0-error:0.21373
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21685
# [2]	validation_0-error:0.21217
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [3]	validation_0-error:0.21373
# [4]	validation_0-error:0.20905
# [5]	validation_0-error:0.20905
# [6]	validation_0-error:0.20281
# [7]	validation_0-error:0.20437
# [8]	validation_0-error:0.21061
# [9]	validation_0-error:0.20281
# [10]	validation_0-error:0.20437
# [11]	validation_0-error:0.20593
# [12]	validation_0-error:0.20905
# [13]	validation_0-error:0.21217
# [14]	validation_0-error:0.20905
# [15]	validation_0-error:0.20593
# [16]	validation_0-error:0.20905
# [17]	validation_0-error:0.21217
# [18]	validation_0-error:0.21373
# [19]	validation_0-error:0.21373
# [20]	validation_0-error:0.21373
# [21]	validation_0-error:0.21685
# [22]	validation_0-error:0.22153
# [23]	validation_0-error:0.22309
# [24]	validation_0-error:0.22309
# [25]	validation_0-error:0.22309
# [26]	validation_0-error:0.22153
# Stopping. Best iteration:
# [6]	validation_0-error:0.20281
#
# [0]	validation_0-error:0.21061
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21373
# [2]	validation_0-error:0.21529
# [3]	validation_0-error:0.21217
# [4]	validation_0-error:0.21061
# [5]	validation_0-error:0.21217
# [6]	validation_0-error:0.21529
# [7]	validation_0-error:0.21061
# [8]	validation_0-error:0.20905
# [9]	validation_0-error:0.21061
# [10]	validation_0-error:0.21373
# [11]	validation_0-error:0.20905
# [12]	validation_0-error:0.20749
# [13]	validation_0-error:0.20905
# [14]	validation_0-error:0.20905
# [15]	validation_0-error:0.20905
# [16]	validation_0-error:0.20749
# [17]	validation_0-error:0.21217
# [18]	validation_0-error:0.21373
# [19]	validation_0-error:0.21217
# [20]	validation_0-error:0.22309
# [21]	validation_0-error:0.22465
# [22]	validation_0-error:0.22621
# [23]	validation_0-error:0.22309
# [24]	validation_0-error:0.22465
# [25]	validation_0-error:0.22153
# [26]	validation_0-error:0.22621
# [27]	validation_0-error:0.22621
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [28]	validation_0-error:0.22777
# [29]	validation_0-error:0.22933
# [30]	validation_0-error:0.23089
# [31]	validation_0-error:0.22777
# [32]	validation_0-error:0.22777
# Stopping. Best iteration:
# [12]	validation_0-error:0.20749
#
# [0]	validation_0-error:0.19657
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.20593
# [2]	validation_0-error:0.20593
# [3]	validation_0-error:0.20593
# [4]	validation_0-error:0.20749
# [5]	validation_0-error:0.20437
# [6]	validation_0-error:0.20437
# [7]	validation_0-error:0.20905
# [8]	validation_0-error:0.21061
# [9]	validation_0-error:0.20749
# [10]	validation_0-error:0.20593
# [11]	validation_0-error:0.20437
# [12]	validation_0-error:0.20749
# [13]	validation_0-error:0.20749
# [14]	validation_0-error:0.20749
# [15]	validation_0-error:0.20905
# [16]	validation_0-error:0.20905
# [17]	validation_0-error:0.20905
# [18]	validation_0-error:0.20749
# [19]	validation_0-error:0.20905
# [20]	validation_0-error:0.20905
# Stopping. Best iteration:
# [0]	validation_0-error:0.19657
#
# [0]	validation_0-error:0.22621
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21997
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [2]	validation_0-error:0.21685
# [3]	validation_0-error:0.20437
# [4]	validation_0-error:0.20905
# [5]	validation_0-error:0.20749
# [6]	validation_0-error:0.20749
# [7]	validation_0-error:0.21061
# [8]	validation_0-error:0.20593
# [9]	validation_0-error:0.20593
# [10]	validation_0-error:0.20593
# [11]	validation_0-error:0.20593
# [12]	validation_0-error:0.21061
# [13]	validation_0-error:0.20749
# [14]	validation_0-error:0.20749
# [15]	validation_0-error:0.20281
# [16]	validation_0-error:0.20593
# [17]	validation_0-error:0.20905
# [18]	validation_0-error:0.21217
# [19]	validation_0-error:0.21061
# [20]	validation_0-error:0.21061
# [21]	validation_0-error:0.21217
# [22]	validation_0-error:0.21061
# [23]	validation_0-error:0.21529
# [24]	validation_0-error:0.21685
# [25]	validation_0-error:0.21529
# [26]	validation_0-error:0.21529
# [27]	validation_0-error:0.21373
# [28]	validation_0-error:0.21373
# [29]	validation_0-error:0.21217
# [30]	validation_0-error:0.21373
# [31]	validation_0-error:0.21529
# [32]	validation_0-error:0.21529
# [33]	validation_0-error:0.21529
# [34]	validation_0-error:0.21685
# [35]	validation_0-error:0.21997
# Stopping. Best iteration:
# [15]	validation_0-error:0.20281
#
# [0]	validation_0-error:0.20125
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.20125
# [2]	validation_0-error:0.20125
# [3]	validation_0-error:0.20281
# [4]	validation_0-error:0.19969
# [5]	validation_0-error:0.20125
# [6]	validation_0-error:0.20125
# [7]	validation_0-error:0.20281
# [8]	validation_0-error:0.19501
# [9]	validation_0-error:0.19345
# [10]	validation_0-error:0.19813
# [11]	validation_0-error:0.19813
# [12]	validation_0-error:0.19501
# [13]	validation_0-error:0.19657
# [14]	validation_0-error:0.19969
# [15]	validation_0-error:0.19969
# [16]	validation_0-error:0.19813
# [17]	validation_0-error:0.19657
# [18]	validation_0-error:0.19813
# [19]	validation_0-error:0.19969
# [20]	validation_0-error:0.19969
# [21]	validation_0-error:0.19969
# [22]	validation_0-error:0.20125
# [23]	validation_0-error:0.20281
# [24]	validation_0-error:0.19969
# [25]	validation_0-error:0.20593
# [26]	validation_0-error:0.20281
# [27]	validation_0-error:0.20437
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [28]	validation_0-error:0.20437
# [29]	validation_0-error:0.20437
# Stopping. Best iteration:
# [9]	validation_0-error:0.19345
#
# [0]	validation_0-error:0.21841
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21373
# [2]	validation_0-error:0.21841
# [3]	validation_0-error:0.21685
# [4]	validation_0-error:0.21217
# [5]	validation_0-error:0.20749
# [6]	validation_0-error:0.20749
# [7]	validation_0-error:0.20905
# [8]	validation_0-error:0.20905
# [9]	validation_0-error:0.20749
# [10]	validation_0-error:0.20593
# [11]	validation_0-error:0.20749
# [12]	validation_0-error:0.20281
# [13]	validation_0-error:0.20749
# [14]	validation_0-error:0.21061
# [15]	validation_0-error:0.20749
# [16]	validation_0-error:0.20749
# [17]	validation_0-error:0.21373
# [18]	validation_0-error:0.21061
# [19]	validation_0-error:0.21373
# [20]	validation_0-error:0.21373
# [21]	validation_0-error:0.21529
# [22]	validation_0-error:0.21217
# [23]	validation_0-error:0.21373
# [24]	validation_0-error:0.21373
# [25]	validation_0-error:0.20905
# [26]	validation_0-error:0.21061
# [27]	validation_0-error:0.20905
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [28]	validation_0-error:0.21373
# [29]	validation_0-error:0.21061
# [30]	validation_0-error:0.21217
# [31]	validation_0-error:0.21217
# [32]	validation_0-error:0.21061
# Stopping. Best iteration:
# [12]	validation_0-error:0.20281
#
# [0]	validation_0-error:0.21061
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.21217
# [2]	validation_0-error:0.21529
# [3]	validation_0-error:0.20437
# [4]	validation_0-error:0.21841
# [5]	validation_0-error:0.21997
# [6]	validation_0-error:0.21529
# [7]	validation_0-error:0.21217
# [8]	validation_0-error:0.21529
# [9]	validation_0-error:0.21373
# [10]	validation_0-error:0.21061
# [11]	validation_0-error:0.21217
# [12]	validation_0-error:0.21685
# [13]	validation_0-error:0.22153
# [14]	validation_0-error:0.21841
# [15]	validation_0-error:0.21841
# [16]	validation_0-error:0.22153
# [17]	validation_0-error:0.22153
# [18]	validation_0-error:0.22465
# [19]	validation_0-error:0.22309
# [20]	validation_0-error:0.22309
# [21]	validation_0-error:0.21841
# [22]	validation_0-error:0.22153
# [23]	validation_0-error:0.21997
# Stopping. Best iteration:
# [3]	validation_0-error:0.20437
# C:\Users\Zoomrx\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv=5, error_score=nan,
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, gamma=0, gpu_id=-1,
#                                      importance_type='gain',
#                                      interaction_constraints='',
#                                      learning_rate=0.300000012,
#                                      max_delta_step=0, max_depth=7,
#                                      min_child_weight=1, missing=nan,
#                                      monotone_constraints='()',
#                                      n_estimators=100, n_job...
#                                      random_state=0, reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, subsample=1,
#                                      tree_method='exact', validate_parameters=1,
#                                      verbosity=None),
#              iid='deprecated', n_jobs=1,
#              param_grid={'eta': [0.01, 0.015, 0.025], 'gamma': [0.1, 0.3, 0.5],
#                          'max_depth': [3, 5, 7, 9, 12],
#                          'min_child_weight': [1, 3, 5, 7]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='f1_weighted', verbose=0)

# %%
print('Best Parameters:',grid.best_params_)
print('Best Score:',grid.best_score_)
# Out:
# Best Parameters: {'eta': 0.01, 'gamma': 0.3, 'max_depth': 9, 'min_child_weight': 5}
# Best Score: 0.8001641798661885

# %% [markdown]
# We can choose n_neighbors has 16 and uniform weights.

# %% [markdown]
# ## Evaluating model performance
#
# Evaluating model performance on the test set using various metrics.

# %%
#Training the model

xgb_model = xgb.XGBClassifier(eta = 0.01, gamma = 0.3, max_depth = 9, min_child_weight =  5)
xgb_model.fit(x_train, y_train.values.ravel())
xgb_y_pred = xgb_model.predict(x_test)

# %% [markdown]
# ### Confusion matrix

# %%
conf_matrix = confusion_matrix(y_test,final_output)
print(conf_matrix)
# Out:
# [[256  73]
#  [ 59 253]]

# %% [markdown]
# - True Positives : 491
# - False Positives : 115
# - False Negatives : 142
# - True Negatives : 533

# %% [markdown]
# ### F1 Score

# %%
f1_value = f1_score(y_test,xgb_y_pred, average = 'weighted') 
print('F1 score:',f1_value)
# Out:
# F1 score: 0.7986695487609661

# %% [markdown]
# ### AUC

# %%
knn_y_pred_proba = knn.predict_proba(x_test)[:,1]
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, knn_y_pred_proba)
roc_auc = auc(false_positive_rate, true_positive_rate)
print('Area under Curve:',roc_auc)
# Out:
# Area under Curve: 0.8578588964227263

# %% [markdown]
# ### Plotting ROC curve

# %%
plt.plot(false_positive_rate, true_positive_rate)
plt.title("ROC Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.show()

# %% [markdown]
# ### Precision and recall values

# %%
class_report = classification_report(y_test,xgb_y_pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.81       329
#            1       0.80      0.78      0.79       312
#
#     accuracy                           0.80       641
#    macro avg       0.80      0.80      0.80       641
# weighted avg       0.80      0.80      0.80       641

# %% [markdown]
# ## Conclusion:
#
# The K Nearest Neighbors model has an AUC score of **0.86** and f1 score of **0.79** on the test set.
